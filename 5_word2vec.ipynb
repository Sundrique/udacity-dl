# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.

from __future__ import print_function
import collections

import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    f = zipfile.ZipFile(filename)
    for name in f.namelist():
        return tf.compat.as_str(f.read(name)).split()
    f.close()


words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5235, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    data:', data[:8])
    print('    data:', [reverse_dictionary[bi] for bi in data[:8]])
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     data: [5235, 3082, 12, 6, 195, 2, 3135, 46]
#     data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     data: [5235, 3082, 12, 6, 195, 2, 3135, 46]
#     data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.259986
# Nearest to is: rohan, enlisting, gaylord, adapts, titles, interpersonal, scientist, boastful,
# Nearest to while: borzois, sculptured, reduced, thant, monist, riding, tribe, morphisms,
# Nearest to for: finders, starry, subnational, byzantine, premise, subdisciplines, distress, antique,
# Nearest to its: forfeit, disappointments, vinland, atari, australasian, shouts, piano, microprogram,
# Nearest to of: musa, redefinition, ohio, precipitate, hermit, scottie, troglodytes, miya,
# Nearest to a: crazed, wedlock, dependent, principled, breakdancing, nucleosome, fools, intermarried,
# Nearest to three: bantu, jalal, suriname, martialed, molds, freelance, sprayed, crunch,
# Nearest to state: abolishes, bonds, punishment, totalled, ramos, renga, dubois, rao,
# Nearest to one: knoll, aronson, edgerton, glamorgan, defeating, corporatist, conjugal, experiences,
# Nearest to it: zombies, sensational, goetz, abilene, pew, polypeptide, divisibility, photosensitive,
# Nearest to have: remixed, khalil, slavs, durban, ww, pas, portfolios, neurotransmitter,
# Nearest to see: shiite, drawbacks, definitely, texan, slapping, nighttime, vincendeau, awaits,
# Nearest to which: horsemen, nol, justly, vf, frivolity, stone, palma, chose,
# Nearest to he: redirected, israeli, nsc, glacier, maritime, zechs, impair, invested,
# Nearest to united: cahill, symbolizes, additive, leakey, infighting, theravada, bankruptcies, eisteddfod,
# Nearest to to: augsburg, ulrike, interpolated, geostationary, customs, tries, consignee, silos,
# Average loss at step 2000: 4.355478
# Average loss at step 4000: 3.862037
# Average loss at step 6000: 3.790096
# Average loss at step 8000: 3.682573
# Average loss at step 10000: 3.611064
# Nearest to is: was, are, has, became, qos, luddite, be, includes,
# Nearest to while: or, tribe, optimates, offended, borzois, reduced, predictable, sculptured,
# Nearest to for: with, of, laundering, in, possessing, pons, proteases, after,
# Nearest to its: his, their, the, s, thrusts, cta, fresnel, apotheosis,
# Nearest to of: in, for, during, troglodytes, bertha, amateur, taupin, chromatids,
# Nearest to a: the, this, any, darmstadt, uncreated, viscous, incapable, remnant,
# Nearest to three: seven, six, eight, four, five, two, nine, zero,
# Nearest to state: abolishes, punishment, enlil, dubois, winter, maclennan, lou, discussing,
# Nearest to one: two, three, eight, six, four, seven, five, nine,
# Nearest to it: he, this, there, which, still, that, what, they,
# Nearest to have: had, be, has, are, were, do, cricketers, colbert,
# Nearest to see: fateh, vincendeau, drawbacks, nighttime, intelligencer, slapping, winslow, spoiled,
# Nearest to which: that, who, it, this, trichomes, also, there, fist,
# Nearest to he: it, she, they, who, there, nsc, also, galindo,
# Nearest to united: cahill, dire, bankruptcies, highest, theravada, redefinition, middle, loser,
# Nearest to to: gardiner, wildly, originals, would, interpolated, marston, not, positing,
# Average loss at step 12000: 3.600597
# Average loss at step 14000: 3.567459
# Average loss at step 16000: 3.401280
# Average loss at step 18000: 3.457713
# Average loss at step 20000: 3.541786
# Nearest to is: was, has, are, hang, were, motivation, be, but,
# Nearest to while: optimates, borzois, tribe, or, reduced, sculptured, offended, kindergarten,
# Nearest to for: locksmiths, with, obe, by, wombat, pons, mocking, buddies,
# Nearest to its: their, his, the, any, freeport, ers, this, her,
# Nearest to of: same, vives, in, emblems, pythagoreans, troglodytes, devil, for,
# Nearest to a: viscous, this, dymaxion, installments, the, any, remnant, strangle,
# Nearest to three: six, seven, four, five, two, eight, nine, zero,
# Nearest to state: winter, masts, punishment, enlil, dubois, abolishes, government, knitting,
# Nearest to one: two, four, seven, eight, three, six, nine, five,
# Nearest to it: he, there, this, they, which, not, no, what,
# Nearest to have: had, has, be, are, were, jester, cricketers, rigs,
# Nearest to see: fateh, intelligencer, vincendeau, unprofitable, adjoint, murmur, illuminism, slapping,
# Nearest to which: who, this, that, also, there, but, still, it,
# Nearest to he: it, she, they, who, there, chargers, galindo, parthia,
# Nearest to united: dire, highest, middle, cahill, gwh, bankruptcies, loser, theravada,
# Nearest to to: trisomy, will, would, can, could, screaming, not, gardiner,
# Average loss at step 22000: 3.503230
# Average loss at step 24000: 3.488398
# Average loss at step 26000: 3.478704
# Average loss at step 28000: 3.477442
# Average loss at step 30000: 3.507671
# Nearest to is: was, has, are, canarian, does, but, became, had,
# Nearest to while: but, optimates, borzois, although, turquoise, is, though, neustria,
# Nearest to for: with, of, international, after, proteases, possessing, sorority, complex,
# Nearest to its: their, his, the, her, glaze, your, a, otherworldly,
# Nearest to of: in, for, endures, and, original, fem, raucous, from,
# Nearest to a: any, no, the, another, their, viscous, principled, scale,
# Nearest to three: four, five, eight, two, seven, six, nine, zero,
# Nearest to state: punishment, government, enlil, masts, winter, macmillan, knitting, springer,
# Nearest to one: two, seven, four, six, three, eight, five, nine,
# Nearest to it: he, there, this, she, they, what, still, no,
# Nearest to have: had, has, are, be, were, colbert, cricketers, rigs,
# Nearest to see: fateh, wilbur, are, recruit, winslow, list, tendons, illuminism,
# Nearest to which: this, that, what, who, also, there, still, it,
# Nearest to he: she, it, they, who, there, but, chargers, galindo,
# Nearest to united: dire, highest, loser, symbolizes, gwh, cahill, redefinition, middle,
# Nearest to to: can, will, would, not, must, gardiner, positing, against,
# Average loss at step 32000: 3.502426
# Average loss at step 34000: 3.490911
# Average loss at step 36000: 3.457107
# Average loss at step 38000: 3.302973
# Average loss at step 40000: 3.427630
# Nearest to is: was, are, has, be, does, rpm, when, if,
# Nearest to while: although, when, borzois, before, though, but, mis, after,
# Nearest to for: in, buddies, mocking, alsos, while, wombat, metaphorically, by,
# Nearest to its: their, his, her, the, xj, joyous, glaze, dropping,
# Nearest to of: in, vives, rad, inoculated, watermelon, lans, ytterbium, from,
# Nearest to a: the, plowing, juliet, any, wedlock, another, musik, installments,
# Nearest to three: four, two, five, six, seven, eight, nine, zero,
# Nearest to state: government, punishment, winter, worsening, masts, springer, economy, macmillan,
# Nearest to one: four, six, seven, two, eight, five, nine, three,
# Nearest to it: he, there, she, this, they, what, which, still,
# Nearest to have: has, had, were, be, are, rigs, bucket, entrusted,
# Nearest to see: list, fateh, recruit, but, wilbur, can, winslow, bauer,
# Nearest to which: that, this, also, who, actually, there, what, still,
# Nearest to he: she, it, they, there, who, i, but, chargers,
# Nearest to united: dire, loser, highest, symbolizes, gwh, bankruptcies, tzu, cahill,
# Nearest to to: will, gardiner, could, can, must, may, sorority, positing,
# Average loss at step 42000: 3.434599
# Average loss at step 44000: 3.455793
# Average loss at step 46000: 3.447192
# Average loss at step 48000: 3.353849
# Average loss at step 50000: 3.385106
# Nearest to is: was, are, has, became, contains, does, navin, makes,
# Nearest to while: although, but, though, when, however, after, where, for,
# Nearest to for: while, including, afternoons, mocking, fantagraphics, metaphorically, dickie, phrasing,
# Nearest to its: their, his, the, her, glaze, your, xj, vcr,
# Nearest to of: in, including, endures, communal, vives, and, schottenheimer, pierre,
# Nearest to a: another, plucking, the, bankhead, any, no, very, atrophy,
# Nearest to three: four, six, seven, eight, five, two, nine, zero,
# Nearest to state: government, worsening, punishment, springer, paleontology, whole, tendencies, technician,
# Nearest to one: two, eight, seven, six, four, five, three, nine,
# Nearest to it: he, she, there, they, this, still, sometimes, what,
# Nearest to have: had, has, were, be, are, bucket, seem, refer,
# Nearest to see: furigana, wilbur, list, fateh, recruit, battlefield, unprofitable, afi,
# Nearest to which: that, this, who, also, actually, what, these, often,
# Nearest to he: she, it, they, who, there, this, clinton, chargers,
# Nearest to united: dire, loser, gwh, symbolizes, bankruptcies, baltic, southern, meta,
# Nearest to to: continental, infinitive, vaishnavism, trisomy, intermittently, screaming, brassiere, through,
# Average loss at step 52000: 3.432665
# Average loss at step 54000: 3.428217
# Average loss at step 56000: 3.443265
# Average loss at step 58000: 3.397204
# Average loss at step 60000: 3.392117
# Nearest to is: was, are, has, although, includes, navin, contains, makes,
# Nearest to while: although, when, though, after, before, sorties, indie, however,
# Nearest to for: including, of, sarris, fantagraphics, mocking, possessing, laundering, without,
# Nearest to its: their, his, the, her, glaze, your, whose, vcr,
# Nearest to of: in, for, vives, ebcdic, although, rad, including, actual,
# Nearest to a: another, the, any, aching, azam, grinnell, atrophy, literate,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to state: government, worsening, whole, city, states, springer, tendencies, gaborone,
# Nearest to one: four, six, two, eight, five, seven, three, nine,
# Nearest to it: he, this, there, she, what, still, which, they,
# Nearest to have: has, had, were, are, seem, bucket, be, logudorese,
# Nearest to see: list, but, include, wilbur, fateh, furigana, references, unprofitable,
# Nearest to which: that, this, what, also, these, however, usually, there,
# Nearest to he: she, it, they, there, greenaway, who, eventually, chargers,
# Nearest to united: dire, gwh, loser, baltic, meta, symbolizes, tzu, bankruptcies,
# Nearest to to: trisomy, must, vaishnavism, would, crankshaft, mba, infinitive, will,
# Average loss at step 62000: 3.244383
# Average loss at step 64000: 3.252236
# Average loss at step 66000: 3.404830
# Average loss at step 68000: 3.397737
# Average loss at step 70000: 3.358108
# Nearest to is: was, has, are, makes, navin, contains, be, although,
# Nearest to while: although, when, though, where, however, and, before, after,
# Nearest to for: while, including, mocking, in, brassiere, locksmiths, pons, sarris,
# Nearest to its: their, his, her, the, your, whose, glaze, vcr,
# Nearest to of: including, in, rad, underage, vives, and, crone, misleadingly,
# Nearest to a: another, the, any, aching, anthropomorphism, grinnell, packard, pangaea,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to state: government, states, city, springer, punishment, snake, whole, worsening,
# Nearest to one: two, six, eight, four, seven, five, three, nine,
# Nearest to it: he, there, she, this, they, still, what, donahue,
# Nearest to have: had, has, were, are, be, logudorese, seem, bucket,
# Nearest to see: wilbur, include, list, but, references, everlast, can, called,
# Nearest to which: that, this, also, what, actually, often, however, but,
# Nearest to he: she, it, they, there, eventually, later, who, we,
# Nearest to united: dire, loser, meta, baltic, gwh, tzu, bankruptcies, nation,
# Nearest to to: must, would, can, sorority, will, vall, may, originals,
# Average loss at step 72000: 3.367203
# Average loss at step 74000: 3.343393
# Average loss at step 76000: 3.315934
# Average loss at step 78000: 3.348957
# Average loss at step 80000: 3.380085
# Nearest to is: was, has, are, rpm, includes, became, although, makes,
# Nearest to while: although, though, however, after, when, or, before, but,
# Nearest to for: including, although, while, gated, after, without, brassiere, in,
# Nearest to its: their, his, your, her, whose, glaze, our, the,
# Nearest to of: in, including, vives, permian, ebcdic, inoculated, av, serialism,
# Nearest to a: another, the, viscous, handicap, plowing, darmstadt, mcclellan, every,
# Nearest to three: four, six, seven, five, two, eight, nine, zero,
# Nearest to state: government, city, punishment, worsening, springer, withered, voles, county,
# Nearest to one: six, seven, two, three, four, eight, five, nine,
# Nearest to it: he, there, she, this, they, still, we, illnesses,
# Nearest to have: had, has, were, are, be, logudorese, seem, want,
# Nearest to see: wilbur, but, list, references, unprofitable, kabyle, links, fateh,
# Nearest to which: that, this, also, what, usually, often, actually, who,
# Nearest to he: she, it, they, there, who, eventually, we, never,
# Nearest to united: meta, dire, loser, gwh, baltic, tzu, redefinition, ismaili,
# Nearest to to: will, must, would, screaming, can, infinitive, should, cannot,
# Average loss at step 82000: 3.403877
# Average loss at step 84000: 3.411810
# Average loss at step 86000: 3.386691
# Average loss at step 88000: 3.353689
# Average loss at step 90000: 3.368961
# Nearest to is: was, has, are, includes, although, kodansha, contains, be,
# Nearest to while: although, when, though, after, before, during, but, were,
# Nearest to for: including, without, after, of, sarris, while, enid, gated,
# Nearest to its: their, his, her, whose, the, your, vcr, centrally,
# Nearest to of: including, for, serialism, accelerates, in, partial, principal, highest,
# Nearest to a: any, another, the, plucking, every, atrophy, positioned, profitability,
# Nearest to three: four, five, two, seven, six, eight, nine, zero,
# Nearest to state: government, city, punishment, messianic, voles, farthest, springer, hardy,
# Nearest to one: four, seven, two, eight, three, six, five, nine,
# Nearest to it: he, she, there, they, this, itself, we, still,
# Nearest to have: had, has, were, are, seem, be, prove, include,
# Nearest to see: wilbur, references, list, external, kabyle, unprofitable, links, but,
# Nearest to which: that, also, this, what, actually, but, who, often,
# Nearest to he: she, it, they, there, who, eventually, but, chargers,
# Nearest to united: meta, baltic, gwh, dire, loser, tzu, border, beginning,
# Nearest to to: will, would, trisomy, intermittently, vaishnavism, jenner, mennonite, originals,
# Average loss at step 92000: 3.396456
# Average loss at step 94000: 3.254704
# Average loss at step 96000: 3.356329
# Average loss at step 98000: 3.242872
# Average loss at step 100000: 3.360472
# Nearest to is: was, has, makes, became, are, seems, be, remains,
# Nearest to while: although, when, though, after, and, before, where, however,
# Nearest to for: sarris, without, alsos, while, after, including, dickie, when,
# Nearest to its: their, his, whose, your, the, our, her, vcr,
# Nearest to of: in, including, watermelon, vives, original, serialism, during, enormous,
# Nearest to a: another, the, any, aching, martian, darmstadt, grinnell, pangaea,
# Nearest to three: five, four, six, two, seven, eight, nine, zero,
# Nearest to state: government, city, springer, messianic, worsening, punishment, agency, hardy,
# Nearest to one: two, four, eight, seven, five, six, three, nine,
# Nearest to it: he, she, there, this, they, affordable, everything, still,
# Nearest to have: had, has, are, were, seem, be, bucket, require,
# Nearest to see: list, references, wilbur, links, external, glare, zebulon, unprofitable,
# Nearest to which: that, this, what, usually, actually, these, who, often,
# Nearest to he: she, it, they, there, who, we, eventually, never,
# Nearest to united: baltic, meta, loser, dire, tzu, border, beginning, gwh,
# Nearest to to: could, will, should, would, must, can, cannot, onto,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points + 1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
